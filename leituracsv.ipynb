# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from collections import Counter

# %% [markdown]
# ### Removendo os valores da coluna "Situação Cadastral" que não sejam "Encerrado" ou "Ativa"

# %%
tdf_relatorio=pd.read_csv("relatorio.csv",sep=';')

df_relatorio = tdf_relatorio[(tdf_relatorio['Situação Cadastral'] == "Encerrado") | (tdf_relatorio['Situação Cadastral'] == "Ativa")]

df_relatorio['Quantidade'] = pd.to_numeric(df_relatorio['Quantidade'], errors='coerce') # Transformar a coluna quantidade em número 

display(df_relatorio.head(5))
# Out:
# C:\Users\henriquelucareli-ieg\AppData\Local\Temp\ipykernel_17872\2194854420.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_relatorio['Quantidade'] = pd.to_numeric(df_relatorio['Quantidade'], errors='coerce') # Transformar a coluna quantidade em número
#                  CNPJ                          Razão Social          Estado  \
# 0  00.024.376/0001-36       IDEAL COMERCIO DE TAMBORES LTDA       SAO PAULO
# 1  00.024.376/0001-36       IDEAL COMERCIO DE TAMBORES LTDA       SAO PAULO
# 2  00.024.376/0001-36       IDEAL COMERCIO DE TAMBORES LTDA       SAO PAULO
# 3  00.060.922/0001-94  COMÉRCIO DE SUCATAS MALLON LTDA - ME  SANTA CATARINA
# 4  00.060.922/0001-94  COMÉRCIO DE SUCATAS MALLON LTDA - ME  SANTA CATARINA
#
#           Município   Ano                                    Tipo de Resíduo  \
# 0         GUARULHOS  2004                  Resíduo inflamável (resinas, etc)
# 1         GUARULHOS  2010                  Resíduo inflamável (resinas, etc)
# 2         GUARULHOS  2012                  Resíduo inflamável (resinas, etc)
# 3  SAO BENTO DO SUL  2009  Embalagens metálicas (latas vazias não contami...
# 4  SAO BENTO DO SUL  2009  Embalagens metálicas (latas vazias não contami...
#
#            Método de Reciclagem  Quantidade Unidade de Medida  \
# 0  Queima em formos industriais       1.000        kilogramas
# 1  Queima em formos industriais      72.000      Ton. por ano
# 2  Queima em formos industriais     111.000      Ton. por ano
# 3                        Outros      26.876           Unidade
# 4                        Outros       2.257           Unidade
#
#                       Empresa Destinadora do Resíduo Situação Cadastral
# 0  40.263.170/0008-50 - SOLVÍ ESSENCIS AMBIENTAL ...              Ativa
# 1          50.856.251/0001-40 - SILCON AMBIENTAL S/A              Ativa
# 2          50.856.251/0001-40 - SILCON AMBIENTAL S/A              Ativa
# 3       07.358.761/0033-46 - GERDAU AÇOS LONGOS S.A.              Ativa
# 4  72.043.862/0001-02 - RANDALL INDUSTRIA E COMÉR...              Ativa

# %% [markdown]
# ## Graficos

# %% [markdown]
# ### Estado

# %%
import matplotlib.pyplot as plt

# Exibindo os valores únicos na coluna 'Estado'
print(df_relatorio['Estado'].unique())

# Contando as ocorrências de cada valor em 'Estado'
contagem_situacao = df_relatorio['Estado'].value_counts()

# Ajustando o tamanho do gráfico
plt.figure(figsize=(35, 10))  # Altere os valores para ajustar o tamanho (largura, altura)

# Criando o gráfico de barras
plt.bar(contagem_situacao.index, contagem_situacao.values, color="red")

# Adicionando os valores acima das barras
for i, valor in enumerate(contagem_situacao.values):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# Configurando os rótulos dos eixos e o título
plt.ylabel('Número de Estado')
plt.xlabel('Estado')
plt.title('Estado por Quantidade')

# Exibindo o gráfico
plt.show()
# Out:
# ['SAO PAULO' 'SANTA CATARINA' 'PARANA' 'GOIAS' 'DISTRITO FEDERAL'
#  'MATO GROSSO DO SUL' 'RIO DE JANEIRO' 'MINAS GERAIS' 'ESPIRITO SANTO'
#  'PARAIBA' 'MATO GROSSO' 'TOCANTINS' 'BAHIA' 'AMAZONAS'
#  'RIO GRANDE DO SUL' 'CEARA' 'MARANHAO' 'PARA' 'RONDONIA' 'PERNAMBUCO'
#  'ALAGOAS' 'SERGIPE' 'PIAUI' 'RIO GRANDE DO NORTE']

# %% [markdown]
# ### Método de Reciclagem

# %%
import matplotlib.pyplot as plt

# Exibindo os valores únicos na coluna 'Município'
print(df_relatorio['Método de Reciclagem'].unique())

# Contando as ocorrências de cada valor em 'Método de Reciclagem'
contagem_situacao = df_relatorio['Método de Reciclagem'].value_counts()

# Ajustando o tamanho do gráfico
plt.figure(figsize=(35, 10))  # Altere os valores para ajustar o tamanho (largura, altura)

# Criando o gráfico de barras
plt.bar(contagem_situacao.index, contagem_situacao.values, color="red")

# Adicionando os valores acima das barras
for i, valor in enumerate(contagem_situacao.values):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# Configurando os rótulos dos eixos e o título
plt.ylabel('Número de Método de Reciclagem')
plt.xlabel('Método de Reciclagem')
plt.title('Método de Reciclagem por Quantidade')

# Exibindo o gráfico
plt.show()
# Out:
# ['Queima em formos industriais' 'Outros' 'Queima caldeira' 'Compostagem'
#  'Neutralização' 'Biológico' 'Fertirigação/landfarming' 'Oxidação química'
#  'Aeração' 'Precipitação' 'Adsorção' 'Secagem' 'Queima a céu aberto'
#  'Vermicompostagem']

# %% [markdown]
# ### Quantidade

# %%
import matplotlib.pyplot as plt

# Exibindo os valores únicos na coluna 'Método de Reciclagem'
print(df_relatorio['Estado'].unique())

# Agrupando por 'Estado' e somando as quantidades
contagem_situacao = df_relatorio.groupby('Estado')['Quantidade'].sum()

# Ajustando o tamanho do gráfico
plt.figure(figsize=(35, 10))  # Altere os valores para ajustar o tamanho (largura, altura)

# Criando o gráfico de barras
plt.bar(contagem_situacao.index, contagem_situacao.values, color="red")

# Adicionando os valores acima das barras
for i, valor in enumerate(contagem_situacao.values):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# Configurando os rótulos dos eixos e o título
plt.ylabel('Quantidade')
plt.xlabel('Estado')
plt.title('Estado por Quantidade')

# Exibindo o gráfico
plt.show()
# Out:
# ['SAO PAULO' 'SANTA CATARINA' 'PARANA' 'GOIAS' 'DISTRITO FEDERAL'
#  'MATO GROSSO DO SUL' 'RIO DE JANEIRO' 'MINAS GERAIS' 'ESPIRITO SANTO'
#  'PARAIBA' 'MATO GROSSO' 'TOCANTINS' 'BAHIA' 'AMAZONAS'
#  'RIO GRANDE DO SUL' 'CEARA' 'MARANHAO' 'PARA' 'RONDONIA' 'PERNAMBUCO'
#  'ALAGOAS' 'SERGIPE' 'PIAUI' 'RIO GRANDE DO NORTE']

# %% [markdown]
# ### Unidade de medida

# %%
import matplotlib.pyplot as plt

# Exibindo os valores únicos na coluna 'Município'
print(df_relatorio['Empresa Destinadora do Resíduo'].unique())

# Contando as ocorrências de cada valor em 'Empresa Destinadora do Resíduo'
contagem_situacao = df_relatorio['Empresa Destinadora do Resíduo'].value_counts()

# Ajustando o tamanho do gráfico
plt.figure(figsize=(35, 10))  # Altere os valores para ajustar o tamanho (largura, altura)

# Criando o gráfico de barras
plt.bar(contagem_situacao.index, contagem_situacao.values, color="red")

# Adicionando os valores acima das barras
for i, valor in enumerate(contagem_situacao.values):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# Configurando os rótulos dos eixos e o título
plt.ylabel('Número de Empresa Destinadora do Resíduo')
plt.xlabel('Empresa Destinadora do Resíduo')
plt.title('Empresa Destinadora do Resíduo por Quantidade')

# Exibindo o gráfico
plt.show()
# Out:
# ['40.263.170/0008-50 - SOLVÍ ESSENCIS AMBIENTAL S.A.'
#  '97.469.506/0001-86 - COMERCIO E TRANSPORTES FELICE MOSER LTDA EPP'
#  '07.358.761/0033-46 - GERDAU AÇOS LONGOS S.A.' ...
#  '46.522.991/0001-73 - PREFEITURA DO MUNICÍPIO DE JANDIRA'
#  '88.318.928/0001-60 - INDUSTRIAL BATISTELLA ARTEFATOS DE BORRACHA LTDA'
#  '88.768.080/0001-70 - MUNICIPIO DE SÃO GABRIEL/RS']

# %% [markdown]
# ### Situação Cadastral

# %%
print(df_relatorio['Situação Cadastral'].unique())

# Contando as ocorrências de cada valor em 'Situação Cadastral'
contagem_situacao = df_relatorio['Situação Cadastral'].value_counts()

# Criando o gráfico de barras
plt.bar(contagem_situacao.index, contagem_situacao.values, color="red")

# Adicionando os valores acima das barras
for i, valor in enumerate(contagem_situacao.values):
    plt.text(i, valor, str(valor), ha='center', va='bottom')

# Configurando os rótulos dos eixos e o título
plt.ylabel('Número de Situação Cadastral')
plt.xlabel('Situação Cadastral')
plt.title('Situação Cadastral por Quantidade')
plt.show()
# Out:
# ['Ativa' 'Encerrado']

# %% [markdown]
# ### Deletando a coluna CNPJ que não sera utilizada.

# %%
df_relatorio=df_relatorio.drop(columns='CNPJ')

# %% [markdown]
# ### Removemos os valores de Unidade de Medida que não eram Kilogramas, porque existiam muitas formas de medidas diferentes indo de "Kilograma" até "Exemplar"

# %%
df_relatorio=(df_relatorio[df_relatorio['Unidade de Medida']=='kilogramas'])

# %% [markdown]
# ### Usando o Z-Score para deixar as quantidades proximas, pois ela são de unidades diferentes.

# %%
media=df_relatorio['Quantidade'].mean()
print("Média das quantidade: ",media)

desvio_padrao=df_relatorio['Quantidade'].std()
print("Desvio padrão de quantidade: ",desvio_padrao)
# Out:
# Média das quantidade:  140.45116757669015
# Desvio padrão de quantidade:  219.2522240438293

# %%
df_relatorio['Quantidade']=(df_relatorio['Quantidade']-media)/desvio_padrao

display(df_relatorio[df_relatorio['Unidade de Medida']=='kilogramas'])
# Out:
#                                             Razão Social             Estado  \
# 0                        IDEAL COMERCIO DE TAMBORES LTDA          SAO PAULO
# 5                   COMÉRCIO DE SUCATAS MALLON LTDA - ME     SANTA CATARINA
# 7                   COMÉRCIO DE SUCATAS MALLON LTDA - ME     SANTA CATARINA
# 9      GSM - CENTRO DE RECICLAGEM E GESTAO AMBIENTAL ...             PARANA
# 10     GSM - CENTRO DE RECICLAGEM E GESTAO AMBIENTAL ...             PARANA
# ...                                                  ...                ...
# 23093                     Votorantim Cimentos Brasil S.A  RIO GRANDE DO SUL
# 23094                     Votorantim Cimentos Brasil S.A  RIO GRANDE DO SUL
# 23095                     Votorantim Cimentos Brasil S.A  RIO GRANDE DO SUL
# 23096                     Votorantim Cimentos Brasil S.A  RIO GRANDE DO SUL
# 23097                     Votorantim Cimentos Brasil S.A  RIO GRANDE DO SUL
#
#                   Município   Ano  \
# 0                 GUARULHOS  2004
# 5          SAO BENTO DO SUL  2009
# 7          SAO BENTO DO SUL  2009
# 9      SAO JOSE DOS PINHAIS  2000
# 10     SAO JOSE DOS PINHAIS  2000
# ...                     ...   ...
# 23093      PINHEIRO MACHADO  2007
# 23094      PINHEIRO MACHADO  2007
# 23095      PINHEIRO MACHADO  2007
# 23096      PINHEIRO MACHADO  2007
# 23097      PINHEIRO MACHADO  2008
#
#                                       Tipo de Resíduo  \
# 0                   Resíduo inflamável (resinas, etc)
# 5                          Resíduo de papel e papelão
# 7                           Sucata de metais ferrosos
# 9         Sucata de metais não ferrosos (latão, etc.)
# 10        Sucata de metais não ferrosos (latão, etc.)
# ...                                               ...
# 23093        Pneus inserviveis/reciclados de caminhão
# 23094        Pneus inserviveis/reciclados de caminhão
# 23095  Pneus inserviveis/reciclados outras aplicações
# 23096  Pneus inserviveis/reciclados outras aplicações
# 23097  Pneus inserviveis/reciclados outras aplicações
#
#                Método de Reciclagem  Quantidade Unidade de Medida  \
# 0      Queima em formos industriais   -0.636031        kilogramas
# 5                            Outros   -0.598353        kilogramas
# 7                            Outros   -0.576515        kilogramas
# 9                            Outros   -0.610809        kilogramas
# 10                           Outros   -0.561505        kilogramas
# ...                             ...         ...               ...
# 23093  Queima em formos industriais   -0.554435        kilogramas
# 23094  Queima em formos industriais   -0.435896        kilogramas
# 23095  Queima em formos industriais   -0.594982        kilogramas
# 23096  Queima em formos industriais   -0.503763        kilogramas
# 23097  Queima em formos industriais   -0.184496        kilogramas
#
#                           Empresa Destinadora do Resíduo Situação Cadastral
# 0      40.263.170/0008-50 - SOLVÍ ESSENCIS AMBIENTAL ...              Ativa
# 5      97.469.506/0001-86 - COMERCIO E TRANSPORTES FE...              Ativa
# 7           07.358.761/0033-46 - GERDAU AÇOS LONGOS S.A.              Ativa
# 9      01.300.758/0001-08 - BOING COMÉRCIO DE METAIS ...              Ativa
# 10              78.404.860/0001-88 - BRASILSAT HARALD SA              Ativa
# ...                                                  ...                ...
# 23093   88.768.080/0001-70 - MUNICIPIO DE SÃO GABRIEL/RS          Encerrado
# 23094  02.669.815/0001-93 - T.M. DE GODOY SOUZA BORRA...          Encerrado
# 23095   88.768.080/0001-70 - MUNICIPIO DE SÃO GABRIEL/RS          Encerrado
# 23096  02.669.815/0001-93 - T.M. DE GODOY SOUZA BORRA...          Encerrado
# 23097  88.318.928/0001-60 - INDUSTRIAL BATISTELLA ART...          Encerrado
#
# [10579 rows x 10 columns]
